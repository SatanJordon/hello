# %% [markdown]
# <a href="https://colab.research.google.com/github/SatanJordon/hello/blob/master/pandas_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Using Python array

# %%
carLoans = [[1, "Sayan" , 23],
            [2, "Raj", 24], 
            [3, "Arijit", 25]]

# %%
colNames = ['Index','Name', 'Age']

# %%
import pandas as pd

# %%
df = pd.DataFrame(data= carLoans, columns=colNames)

# %%
df
# Out:
#    Index    Name  Age
# 0      1   Sayan   23
# 1      2     Raj   24
# 2      3  Arijit   25

# %%
import numpy as np

# %% [markdown]
# Using Numpy Array Most effiecient

# %%
carLoans = np.array([
            [1, "Sayan" , 23],
            [2, "Raj", 24], 
            [3, "Arijit", 25]
])

# %%
df = pd.DataFrame(data= carLoans, columns=colNames)

# %%
df
# Out:
#   Index    Name Age
# 0     1   Sayan  23
# 1     2     Raj  24
# 2     3  Arijit  25

# %% [markdown]
# Using Dictionary

# %%
carLoans={ 'Index' : {0:1,1:2,2:3},
            'Name' : {0:'Sayan',1:'Raj', 2:'Arijit'},
            'Age': {0:23,1:24,2:25}}

# %%
df = pd.DataFrame(data= carLoans, columns=colNames)

# %%
df
# Out:
#    Index    Name  Age
# 0      1   Sayan   23
# 1      2     Raj   24
# 2      3  Arijit   25

# %% [markdown]
# help pd. dataframe

# %%
help(pd.DataFrame)

# %% [markdown]
# Load Csv

# %%
filename = 'data/car_financing.csv'
df = pd.read_csv(filename)

# %%
df

# %% [markdown]
# load from xcls

# %%
filename = 'data/car_financing.xlsx'
df = pd.read_excel(filename)

# %%
df

# %%
df.head()
# Out:
#    Month  Starting Balance  Repayment  ...  term  interest_rate       car_type
# 0      1          34689.96     687.23  ...    60         0.0702  Toyota Sienna
# 1      2          34205.66     687.23  ...    60         0.0702  Toyota Sienna
# 2      3          33718.53     687.23  ...    60         0.0702  Toyota Sienna
# 3      4          33228.55     687.23  ...    60         0.0702  Toyota Sienna
# 4      5          32735.70     687.23  ...    60         0.0702  Toyota Sienna
#
# [5 rows x 9 columns]

# %%
df.tail()
# Out:
#      Month  Starting Balance  Repayment  ...  term  interest_rate   car_type
# 403     56           3951.11     796.01  ...    60          0.029  VW Golf R
# 404     57           3164.64     796.01  ...    60          0.029  VW Golf R
# 405     58           2376.27     796.01  ...    60          0.029  VW Golf R
# 406     59           1586.00     796.01  ...    60          0.029  VW Golf R
# 407     60            793.82     796.01  ...    60          0.029  VW Golf R
#
# [5 rows x 9 columns]

# %%
df.dtypes
# Out:
# Month                 int64
# Starting Balance    float64
# Repayment           float64
# Interest Paid       float64
# Principal Paid      float64
# New Balance         float64
# term                  int64
# interest_rate       float64
# car_type             object
# dtype: object

# %%
df.shape
# Out:
# (408, 9)

# %%
df.info()

# %%
df.head()
# Out:
#    Month  Starting Balance  Repayment  ...  term  interest_rate       car_type
# 0      1          34689.96     687.23  ...    60         0.0702  Toyota Sienna
# 1      2          34205.66     687.23  ...    60         0.0702  Toyota Sienna
# 2      3          33718.53     687.23  ...    60         0.0702  Toyota Sienna
# 3      4          33228.55     687.23  ...    60         0.0702  Toyota Sienna
# 4      5          32735.70     687.23  ...    60         0.0702  Toyota Sienna
#
# [5 rows x 9 columns]

# %%
df[['car_type', 'Principal Paid']].head()
# Out:
#         car_type  Principal Paid
# 0  Toyota Sienna          484.30
# 1  Toyota Sienna          487.13
# 2  Toyota Sienna          489.98
# 3  Toyota Sienna          492.85
# 4  Toyota Sienna          495.73

# %%
df['car_type'][20:24]
# Out:
# 20    Toyota Sienna
# 21    Toyota Sienna
# 22    Toyota Sienna
# 23    Toyota Sienna
# Name: car_type, dtype: object

# %%
df.loc[:, ['car_type']].head()

# %%
df['car_type'].value_counts()
# Out:
# VW Golf R         144
# Toyota Sienna     120
# Toyota Carolla    111
# Toyota Corolla     33
# Name: car_type, dtype: int64

# %%
car_filter_carolla = df['car_type'] == 'Toyota Sienna'

# %%
car_filter_carolla.head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: car_type, dtype: bool

# %%
df[car_filter_carolla].head()
# Out:
#    Month  Starting Balance  Repayment  ...  term  interest_rate       car_type
# 0      1          34689.96     687.23  ...    60         0.0702  Toyota Sienna
# 1      2          34205.66     687.23  ...    60         0.0702  Toyota Sienna
# 2      3          33718.53     687.23  ...    60         0.0702  Toyota Sienna
# 3      4          33228.55     687.23  ...    60         0.0702  Toyota Sienna
# 4      5          32735.70     687.23  ...    60         0.0702  Toyota Sienna
#
# [5 rows x 9 columns]

# %%
df.loc[car_filter_carolla, :]
# Out:
# Empty DataFrame
# Columns: [Month, Starting Balance, Repayment, Interest Paid, Principal Paid, New Balance, term, interest_rate, car_type]
# Index: []

# %%
df['interest_rate'].value_counts()
# Out:
# 0.0290    144
# 0.0390    144
# 0.0359     60
# 0.0702     60
# Name: interest_rate, dtype: int64

# %%
interest_fiter = df['interest_rate'] == 0.0702

# %%
df=df.loc[interest_fiter, :]

# %%
df['interest_rate'].value_counts()
# Out:
# 0.0702    60
# Name: interest_rate, dtype: int64

# %%
df.loc[car_filter_carolla & interest_fiter, :]
# Out:
#     Month  Starting Balance  Repayment  ...  term  interest_rate       car_type
# 0       1          34689.96     687.23  ...    60         0.0702  Toyota Sienna
# 1       2          34205.66     687.23  ...    60         0.0702  Toyota Sienna
# 2       3          33718.53     687.23  ...    60         0.0702  Toyota Sienna
# 3       4          33228.55     687.23  ...    60         0.0702  Toyota Sienna
# 4       5          32735.70     687.23  ...    60         0.0702  Toyota Sienna
# 5       6          32239.97     687.23  ...    60         0.0702  Toyota Sienna
# 6       7          31741.34     687.23  ...    60         0.0702  Toyota Sienna
# 7       8          31239.79     687.23  ...    60         0.0702  Toyota Sienna
# 8       9          30735.31     687.23  ...    60         0.0702  Toyota Sienna
# 9      10          30227.88     687.23  ...    60         0.0702  Toyota Sienna
# 10     11          29717.48     687.23  ...    60         0.0702  Toyota Sienna
# ...
